# %%
from sklearn.datasets import make_classification

# %%
X,Y=make_classification( n_redundant=0, n_samples=1000,n_features=2,n_clusters_per_class=1,weights=[0.90], random_state=12)
X
# Y
# Out:
# array([[-0.76289759, -0.70680807],
#        [-1.07543571, -1.0511621 ],
#        [-0.61011459, -0.90980157],
#        ...,
#        [-1.32643852, -1.815178  ],
#        [-0.83348573, -0.5146474 ],
#        [-0.30287558, -0.57597532]], shape=(1000, 2))

# %%
import pandas as pd
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(Y, columns=['target'])
final_df = pd.concat([df1,df2], axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from imblearn.over_sampling import SMOTE

# %%
## Transform the dataset
oversample = SMOTE()
X,Y = oversample.fit_resample(final_df[['f1', 'f2']], final_df['target'])
X.shape
# Out:
# (1800, 2)

# %%
Y.shape
# Out:
# (1800,)

# %%
len(Y[Y==0]) # How many 'zero's' present in dataset
# Out:
# 900

# %%
len(Y[Y==1])
# Out:
# 900

# %%
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(Y, columns=['target'])
oversampled_df = pd.concat([df1,df2], axis=1)

# %%
plt.scatter(oversampled_df['f1'], oversampled_df['f2'], c=oversampled_df['target'])
